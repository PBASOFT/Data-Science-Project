# %%
# !pip3 install pandas_datareader
# !pip3 install psycopg2
# Out:
# ...
#      |████████████████████████████████| 383 kB 5.3 MB/s eta 0:00:01
# ...
#   Created wheel for psycopg2: filename=psycopg2-2.8.6-cp38-cp38-macosx_10_9_x86_64.whl size=136240 sha256=e85a7440402a4be13feb7bdb6a930447acdf0cfb5c316edd5a637f89e87fe619
#   Stored in directory: /Users/malenehansen/Library/Caches/pip/wheels/70/5e/69/8a020d78c09043156a7df0b64529e460fbd922ca065c4b795c
# Successfully built psycopg2
# ...

# %%
# %run stock_price_saver.py
# Out:
# 2020-12-10     4.090000
# 2020-12-11     3.920000
# 2020-12-12     3.920000
# 2020-12-13     3.920000
# 2020-12-14     3.190000
#                 ...
# 2021-05-26    19.559999
# 2021-05-27    26.520000
# 2021-05-28    26.120001
# 2021-05-29    26.120001
# 2021-05-30    26.120001
# Freq: D, Name: Adj Close, Length: 172, dtype: float64
# 2020-12-10    27.040001
# 2020-12-11    27.200001
# 2020-12-12    27.200001
# 2020-12-13    27.200001
# 2020-12-14    27.240000
#                 ...
# 2021-05-26    22.120001
# 2021-05-27    22.700001
# 2021-05-28    22.950001
# 2021-05-29    22.950001
# 2021-05-30    22.950001
# Freq: D, Name: Adj Close, Length: 172, dtype: float64
# 2020-12-10    1.74
# 2020-12-11    1.71
# 2020-12-12    1.71
# 2020-12-13    1.71
# 2020-12-14    1.70
#               ...
# 2021-05-26    2.44
# 2021-05-27    2.83
# 2021-05-28    2.85
# 2021-05-29    2.85
# 2021-05-30    2.85
# Freq: D, Name: Adj Close, Length: 172, dtype: float64
# 2020-12-10    18.17
# ...
